# %% [markdown]
# # Polynomial Regression - Salary Example

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
X_train = [[6000],[8200],[9000],[14200],[16200]]
y_train = [[86000],[82000],[78000],[75000],[70000]]

X_test = [[6000],[8200],[9000],[14200],[16200]]
y_test = [[94000],[83000],[77000],[73000],[63000]]

# %%
model = LinearRegression()
model.fit(X_train, y_train)
xx = np.linspace(0, 25000, 150000)
yy = model.predict(xx.reshape(xx.shape[0], 1))

# %%
polinom_derecesi = PolynomialFeatures(degree = 2)
X_train_polinom = polinom_derecesi.fit_transform(X_train)
X_test_polinom = polinom_derecesi.fit_transform(X_test)

# %%
polinom_regression = LinearRegression()
polinom_regression.fit(X_train_polinom, y_train)
# Out:
# LinearRegression()

# %%
xx_polinom = polinom_derecesi.fit_transform(xx.reshape(xx.shape[0], 1))
yy_polinom = polinom_regression.predict(xx_polinom)
print(xx_polinom)
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.66667778e-01 2.77781482e-02]
#  [1.00000000e+00 3.33335556e-01 1.11112593e-01]
#  ...
#  [1.00000000e+00 2.49996667e+04 6.24983333e+08]
#  [1.00000000e+00 2.49998333e+04 6.24991667e+08]
#  [1.00000000e+00 2.50000000e+04 6.25000000e+08]]

# %%
polinom_regression.intercept_
# Out:
# array([99393.54577624])

# %%
polinom_regression.coef_
# Out:
# array([[ 0.00000000e+00, -2.66306426e+00,  5.67196997e-05]])

# %%
plt.figure()
plt.title("Polynomial Regression Prediction")
plt.xlabel("KM")
plt.ylabel("Price")
plt.plot(xx, polinom_regression.predict(xx_polinom), c = "r", linestyle = "-")
plt.axis([3000,22500, 65000, 95000])
plt.grid(True)
plt.scatter(X_train, y_train, color="black")
plt.show()
